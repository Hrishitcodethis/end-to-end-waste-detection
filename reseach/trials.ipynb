# %%
import gdown
import os

# %%
url = "https://drive.google.com/file/d/12m7cwT2xmxSx5eXIii6Su3X3xfbPrOzK/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '12m7cwT2xmxSx5eXIii6Su3X3xfbPrOzK'

# %%
os.chdir("../")

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "data/waste_data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=12m7cwT2xmxSx5eXIii6Su3X3xfbPrOzK
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=12m7cwT2xmxSx5eXIii6Su3X3xfbPrOzK&confirm=t&uuid=7804c610-10fa-4e62-a781-423543b5b143
# To: /Users/hrishityelchuri/Desktop/github/end-to-end-waste-detection/data/waste_data.zip
# 100%|██████████| 40.1M/40.1M [00:01<00:00, 20.1MB/s]
# 'data/waste_data.zip'
